# %%
#import modules
import pandas as pd
import numpy as np

# %%
#read csv file
path="C:/Users/Toni Di Shaka/Documents/GitHub/jupyter_notebook/Artist/Artist.csv"
data=pd.read_csv(path)

# %%
#view dataset
data
# Out:
#    Unnamed: 0           Artist                      Album   Released  \
# 0           0  Michael Jackson                   Thriller  30-Nov-82
# 1           1            AC/DC              Back in Black  25-Jul-80
# 2           2       Pink Floyd  The Dark Side of the Moon  01-Mar-73
# 3           3  Whitney Houston              The Bodyguard  25-Jul-80
# 4           4        Meat Loaf            Bat out of Hell  21-Oct-77
#
#      Length             Genre  Sales(millions)  Claimed sales(millions)  \
# 0  00.42.19      Pop,rock,R$B             46.0                       65
# 1  00.42.11         Hard rock             26.1                       50
# 2  00.42.49  Progressive rock             24.2                       45
# 3  00.57.44               Pop             26.1                       50
# 4  00.46.33         Hard rock             20.6                       43
#
#    Rating
# 0    10.0
# 1     8.5
# 2     9.5
# 3     7.0
# 4     7.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               5 non-null      int64
#  1   Artist                   5 non-null      object
#  2   Album                    5 non-null      object
#  3   Released                 5 non-null      object
#  4   Length                   5 non-null      object
#  5   Genre                    5 non-null      object
#  6   Sales(millions)          5 non-null      float64
#  7   Claimed sales(millions)  5 non-null      int64
#  8   Rating                   5 non-null      float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 488.0+ bytes

# %%
#sort column Rating in descending order 
data.sort_values(by='Rating',ascending=False)
# Out:
#    Unnamed: 0           Artist                      Album   Released  \
# 0           0  Michael Jackson                   Thriller  30-Nov-82
# 2           2       Pink Floyd  The Dark Side of the Moon  01-Mar-73
# 1           1            AC/DC              Back in Black  25-Jul-80
# 3           3  Whitney Houston              The Bodyguard  25-Jul-80
# 4           4        Meat Loaf            Bat out of Hell  21-Oct-77
#
#      Length             Genre  Sales(millions)  Claimed sales(millions)  \
# 0  00.42.19      Pop,rock,R$B             46.0                       65
# 2  00.42.49  Progressive rock             24.2                       45
# 1  00.42.11         Hard rock             26.1                       50
# 3  00.57.44               Pop             26.1                       50
# 4  00.46.33         Hard rock             20.6                       43
#
#    Rating
# 0    10.0
# 2     9.5
# 1     8.5
# 3     7.0
# 4     7.0

# %%
#Which album is Pop
data[data['Genre'].isin(['Pop'])]
# Out:
#    Unnamed: 0           Artist          Album   Released    Length Genre  \
# 3           3  Whitney Houston  The Bodyguard  25-Jul-80  00.57.44   Pop
#
#    Sales(millions)  Claimed sales(millions)  Rating
# 3             26.1                       50     7.0

# %%
#Which album is Hard rock
data[data['Genre'].isin(['Hard rock'])]
# Out:
#    Unnamed: 0     Artist            Album   Released    Length      Genre  \
# 1           1      AC/DC    Back in Black  25-Jul-80  00.42.11  Hard rock
# 4           4  Meat Loaf  Bat out of Hell  21-Oct-77  00.46.33  Hard rock
#
#    Sales(millions)  Claimed sales(millions)  Rating
# 1             26.1                       50     8.5
# 4             20.6                       43     7.0

# %%
#Which album is Progressive rock
data[data['Genre'].isin(['Progressive rock'])]
# Out:
#    Unnamed: 0      Artist                      Album   Released    Length  \
# 2           2  Pink Floyd  The Dark Side of the Moon  01-Mar-73  00.42.49
#
#               Genre  Sales(millions)  Claimed sales(millions)  Rating
# 2  Progressive rock             24.2                       45     9.5

# %%
#sort column Album from max claimed sales to least claimed sales
data[['Artist','Album','Claimed sales(millions)']].sort_values(by='Claimed sales(millions)',ascending=False)
# Out:
#             Artist                      Album  Claimed sales(millions)
# 0  Michael Jackson                   Thriller                       65
# 1            AC/DC              Back in Black                       50
# 3  Whitney Houston              The Bodyguard                       50
# 2       Pink Floyd  The Dark Side of the Moon                       45
# 4        Meat Loaf            Bat out of Hell                       43
